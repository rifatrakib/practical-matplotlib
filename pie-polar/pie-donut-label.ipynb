# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def formatter(pct, all_values):
    absolute = int(np.round(pct / 100 * np.sum(all_values)))
    return f"{pct:.1f}%\n({absolute} g)"

# %%
recipe = ["375 g flour", "75 g sugar", "250 g butter", "300 g berries"]
data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw={"aspect": "equal"})

wedges, text, autotexts = ax.pie(
    data, autopct=lambda pct: formatter(pct, data), textprops={"color": "w"},
)
ax.legend(
    wedges, ingredients, title="ingredients",
    loc="center left", bbox_to_anchor=(1, 0, 0.5, 1),
)
plt.setp(autotexts, size=8, weight="bold")
ax.set_title("pie bakery")

plt.show()

# %%
recipe = [
    "225 g flour", "90 g sugar", "1 egg", "60 g butter",
    "100 ml milk", "1/2 package of yeast",
]
data = [225, 90, 50, 60, 100, 5]

bbox_props = {"boxstyle": "square,pad=0.3", "fc": "w", "ec": "k", "lw": 0.72}
kw = {"arrowprops": {"arrowstyle": "-"}, "bbox": bbox_props, "zorder": 0, "va": "center"}

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw={"aspect": "equal"})

wedges, texts = ax.pie(data, wedgeprops={"width": 0.5}, startangle=-40)

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1) / 2.0 + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = f"angle,angleA=0,angleB={ang}"
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(
        recipe[i], xy=(x, y), xytext=(1.35 * np.sign(x), 1.4 * y),
        horizontalalignment=horizontalalignment, **kw
    )

ax.set_title("donut bakery")
plt.show()
