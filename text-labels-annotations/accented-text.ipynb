# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

ax.plot(range(10))
ax.set_title(
    r"$\ddot{o}\acute{e}\grave{e}\hat{0}"
    r"\breve{i}\bar{A}\tilde{n}\vec{q}$", fontsize=20,
)
ax.set_xlabel(r"""$\"o\ddot o \'e\`e\~n\.x\^y$""", fontsize=20)
ax.text(4, 0.5, r"$F=m\ddot{x}$")

fig.tight_layout()
plt.show()
