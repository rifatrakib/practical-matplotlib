# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def annotate_plot(ax, x, y, title):
    x_mesh, y_mesh = np.meshgrid(x, y)
    ax.plot(x_mesh.flat, y_mesh.flat, "o", color="m")
    ax.set_xlim(-0.7, 5.2)
    ax.set_ylim(-0.7, 3.2)
    ax.set_title(title)

# %%
n_rows = 3
n_cols = 5

z = np.arange(n_rows * n_cols).reshape(n_rows, n_cols)
x = np.arange(n_cols + 1)
y = np.arange(n_rows + 1)

# %%
fig, ax = plt.subplots()
ax.pcolormesh(x, y, z, shading="flat", vmin=z.min(), vmax=z.max())
annotate_plot(ax, x, y, "shading=flat")
plt.show()

# %%
x = np.arange(n_cols)
y = np.arange(n_rows)

# %%
fig, ax = plt.subplots()
ax.pcolormesh(x, y, z[:-1, :-1], shading="flat", vmin=z.min(), vmax=z.max())
annotate_plot(ax, x, y, "shading=x, y, z same shape")
plt.show()

# %%
fig, ax = plt.subplots()
ax.pcolormesh(x, y, z, shading="nearest", vmin=z.min(), vmax=z.max())
annotate_plot(ax, x, y, "shading=nearest")
plt.show()
